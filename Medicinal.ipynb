# %% [markdown]
# <a href="https://colab.research.google.com/github/AusafMo/NoteBook-Medicinal-Herb-Model-ResNet/blob/main/Medicinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/medicinal/leaf.zip', 'r') # Opens the zip file in read mode
zip_ref.extractall('/leaf') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
import torch
from collections import Counter
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
import os
from glob import glob
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Data science tools
import numpy as np
import pandas as pd
import os

# Image manipulations
from PIL import Image

from timeit import default_timer as timer

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 14

# %% [markdown]
# ---
# # **Importing Files**
# Restructering and Renaming Directories
# ---

# %%
ImagePATH = f"/leaf/"

# %%
from glob import glob
types = glob(ImagePATH+"*")

# %%
print(types)
# Out:
# ['/leaf/Jasminum (Jasmine)', '/leaf/Nyctanthes Arbor-tristis (Parijata)', '/leaf/Azadirachta Indica (Neem)', '/leaf/Ficus Auriculata (Roxburgh fig)', '/leaf/Tabernaemontana Divaricata (Crape Jasmine)', '/leaf/Nerium Oleander (Oleander)', '/leaf/Muntingia Calabura (Jamaica Cherry-Gasagase)', '/leaf/Alpinia Galanga (Rasna)', '/leaf/Citrus Limon (Lemon)', '/leaf/Mangifera Indica (Mango)', '/leaf/Ficus Religiosa (Peepal Tree)', '/leaf/Ocimum Tenuiflorum (Tulsi)', '/leaf/Brassica Juncea (Indian Mustard)', '/leaf/Santalum Album (Sandalwood)', '/leaf/Amaranthus Viridis (Arive-Dantu)', '/leaf/Psidium Guajava (Guava)', '/leaf/Basella Alba (Basale)', '/leaf/Carissa Carandas (Karanda)', '/leaf/Syzygium Jambos (Rose Apple)', '/leaf/Pongamia Pinnata (Indian Beech)', '/leaf/Murraya Koenigii (Curry)', '/leaf/Piper Betle (Betel)', '/leaf/Punica Granatum (Pomegranate)', '/leaf/Syzygium Cumini (Jamun)', '/leaf/Moringa Oleifera (Drumstick)', '/leaf/Artocarpus Heterophyllus (Jackfruit)', '/leaf/Trigonella Foenum-graecum (Fenugreek)', '/leaf/Plectranthus Amboinicus (Mexican Mint)', '/leaf/Hibiscus Rosa-sinensis', '/leaf/Mentha (Mint)']

# %%
# Making DATAFRAME

filedf = pd.DataFrame()
for typ in types:
    files = glob(typ + "/*" )
    tempdf = pd.DataFrame( { 'filepath' : files, 'types':typ.split("/")[-1]} )
    filedf = pd.concat( [ filedf, tempdf ] )

# %%
print(filedf)
# Out:
#                                 filepath               types
# 0   /leaf/Jasminum (Jasmine)/J-S-054.jpg  Jasminum (Jasmine)
# 1   /leaf/Jasminum (Jasmine)/J-S-041.jpg  Jasminum (Jasmine)
# 2   /leaf/Jasminum (Jasmine)/J-S-029.jpg  Jasminum (Jasmine)
# 3   /leaf/Jasminum (Jasmine)/J-S-034.jpg  Jasminum (Jasmine)
# 4   /leaf/Jasminum (Jasmine)/J-S-068.jpg  Jasminum (Jasmine)
# ..                                   ...                 ...
# 92       /leaf/Mentha (Mint)/M-S-082.jpg       Mentha (Mint)
# 93       /leaf/Mentha (Mint)/M-S-057.jpg       Mentha (Mint)
# 94       /leaf/Mentha (Mint)/M-S-009.jpg       Mentha (Mint)
# 95       /leaf/Mentha (Mint)/M-S-077.jpg       Mentha (Mint)
# 96       /leaf/Mentha (Mint)/M-S-003.jpg       Mentha (Mint)
#
# [1835 rows x 2 columns]

# %% [markdown]
# ### ***Grouping the types and arranging them by their count ( number of samples )***

# %%
gby_cnt = filedf.groupby( "types" ).aggregate( 'count' ).rename( columns = {'filepath' : 'cnt' } ).reset_index().sort_values( by = 'cnt', ascending = False )

# %%
gby_cnt
# Out:
#                                            types  cnt
# 1               Amaranthus Viridis (Arive-Dantu)  122
# 4                          Basella Alba (Basale)  103
# 13                                 Mentha (Mint)   97
# 24                 Punica Granatum (Pomegranate)   79
# 14                  Moringa Oleifera (Drumstick)   77
# 6                     Carissa Carandas (Karanda)   74
# 11                            Jasminum (Jasmine)   71
# 23                       Psidium Guajava (Guava)   65
# 9                  Ficus Religiosa (Peepal Tree)   63
# 17                    Nerium Oleander (Oleander)   62
# 12                      Mangifera Indica (Mango)   62
# 22               Pongamia Pinnata (Indian Beech)   61
# 3                      Azadirachta Indica (Neem)   60
# 16                      Murraya Koenigii (Curry)   60
# 25                   Santalum Album (Sandalwood)   58
# 7                           Citrus Limon (Lemon)   57
# 27                  Syzygium Jambos (Rose Apple)   56
# 28    Tabernaemontana Divaricata (Crape Jasmine)   56
# 2           Artocarpus Heterophyllus (Jackfruit)   56
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)   56
# 19                    Ocimum Tenuiflorum (Tulsi)   52
# 0                        Alpinia Galanga (Rasna)   50
# 8                Ficus Auriculata (Roxburgh fig)   50
# 21        Plectranthus Amboinicus (Mexican Mint)   48
# 20                           Piper Betle (Betel)   48
# 10                        Hibiscus Rosa-sinensis   43
# 18           Nyctanthes Arbor-tristis (Parijata)   40
# 26                       Syzygium Cumini (Jamun)   39
# 29         Trigonella Foenum-graecum (Fenugreek)   36
# 5               Brassica Juncea (Indian Mustard)   34

# %%
fig = px.bar( gby_cnt, x = 'types', y = 'cnt', color = 'types', title = 'Counts from Each Types')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cba7c017-085f-4d01-995d-e4c8029e0c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cba7c017-085f-4d01-995d-e4c8029e0c8f")) {                    Plotly.newPlot(                        "cba7c017-085f-4d01-995d-e4c8029e0c8f",                        [{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaranthus Viridis (Arive-Dantu)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Amaranthus Viridis (Arive-Dantu)","offsetgroup":"Amaranthus Viridis (Arive-Dantu)","orientation":"v","showlegend":true,"textposition":"auto","x":["Amaranthus Viridis (Arive-Dantu)"],"xaxis":"x","y":[122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basella Alba (Basale)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Basella Alba (Basale)","offsetgroup":"Basella Alba (Basale)","orientation":"v","showlegend":true,"textposition":"auto","x":["Basella Alba (Basale)"],"xaxis":"x","y":[103],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mentha (Mint)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mentha (Mint)","offsetgroup":"Mentha (Mint)","orientation":"v","showlegend":true,"textposition":"auto","x":["Mentha (Mint)"],"xaxis":"x","y":[97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Punica Granatum (Pomegranate)","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Punica Granatum (Pomegranate)","offsetgroup":"Punica Granatum (Pomegranate)","orientation":"v","showlegend":true,"textposition":"auto","x":["Punica Granatum (Pomegranate)"],"xaxis":"x","y":[79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moringa Oleifera (Drumstick)","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Moringa Oleifera (Drumstick)","offsetgroup":"Moringa Oleifera (Drumstick)","orientation":"v","showlegend":true,"textposition":"auto","x":["Moringa Oleifera (Drumstick)"],"xaxis":"x","y":[77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carissa Carandas (Karanda)","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Carissa Carandas (Karanda)","offsetgroup":"Carissa Carandas (Karanda)","orientation":"v","showlegend":true,"textposition":"auto","x":["Carissa Carandas (Karanda)"],"xaxis":"x","y":[74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jasminum (Jasmine)","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Jasminum (Jasmine)","offsetgroup":"Jasminum (Jasmine)","orientation":"v","showlegend":true,"textposition":"auto","x":["Jasminum (Jasmine)"],"xaxis":"x","y":[71],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Psidium Guajava (Guava)","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Psidium Guajava (Guava)","offsetgroup":"Psidium Guajava (Guava)","orientation":"v","showlegend":true,"textposition":"auto","x":["Psidium Guajava (Guava)"],"xaxis":"x","y":[65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003e ...

# %%
# !mkdir outputs

# %%
gby_cnt.to_csv(f"outputs/types_counts.csv", index = None )

# %% [markdown]
# # **Checking Some Data Samples**

# %%
plt.figure( figsize = ( 20, 20 ) )

for i in range(10):

    path = filedf.sample( 1 )['filepath'].values[0]
    types = path.split( "/" )[2]
    ex_img = Image.open(path)
    ax = plt.subplot( 4, 4, i + 1 )
    ax.annotate( types, xy = ( 0.1, 0.9 ), xycoords = " axes fraction ", weight = 'light', size = 10 )
    ax.imshow(ex_img)

plt.show()

# %% [markdown]
# # **Splitting the DataSet into Train Test Split**

# %%
print("dataframe length:", len(filedf))

print(filedf.types.value_counts().head(10))

print("total samples: ", filedf.types.value_counts().sum())
# Out:
# dataframe length: 1835
# Amaranthus Viridis (Arive-Dantu)    122
# Basella Alba (Basale)               103
# Mentha (Mint)                        97
# Punica Granatum (Pomegranate)        79
# Moringa Oleifera (Drumstick)         77
# Carissa Carandas (Karanda)           74
# Jasminum (Jasmine)                   71
# Psidium Guajava (Guava)              65
# Ficus Religiosa (Peepal Tree)        63
# Mangifera Indica (Mango)             62
# Name: types, dtype: int64
# total samples:  1835

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
        filedf, filedf['types'], stratify = filedf['types'], test_size=0.4)

X_test, X_val, Y_test, Y_val = train_test_split(
        X_test, X_test['types'], stratify = X_test['types'], test_size=0.5)

# %%
X_train
# Out:
#                                             filepath  \
# 40       /leaf/Murraya Koenigii (Curry)/MK-S-040.jpg
# 47       /leaf/Mangifera Indica (Mango)/MI-S-057.jpg
# 20        /leaf/Syzygium Cumini (Jamun)/SC-S-026.jpg
# 42    /leaf/Santalum Album (Sandalwood)/SA-S-048.jpg
# 23            /leaf/Piper Betle (Betel)/PB-S-034.jpg
# ..                                               ...
# 24          /leaf/Basella Alba (Basale)/BA-S-058.jpg
# 31         /leaf/Hibiscus Rosa-sinensis/HR-S-019.jpg
# 43       /leaf/Mangifera Indica (Mango)/MI-S-047.jpg
# 35              /leaf/Jasminum (Jasmine)/J-S-026.jpg
# 19  /leaf/Ficus Religiosa (Peepal Tree)/FR-S-018.jpg
#
#                             types
# 40       Murraya Koenigii (Curry)
# 47       Mangifera Indica (Mango)
# 20        Syzygium Cumini (Jamun)
# 42    Santalum Album (Sandalwood)
# 23            Piper Betle (Betel)
# ..                            ...
# 24          Basella Alba (Basale)
# 31         Hibiscus Rosa-sinensis
# 43       Mangifera Indica (Mango)
# 35             Jasminum (Jasmine)
# 19  Ficus Religiosa (Peepal Tree)
#
# [1101 rows x 2 columns]

# %%
X_test
# Out:
#                                               filepath  \
# 42         /leaf/Murraya Koenigii (Curry)/MK-S-047.jpg
# 11   /leaf/Nyctanthes Arbor-tristis (Parijata)/NA-S...
# 100  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-01...
# 28   /leaf/Brassica Juncea (Indian Mustard)/BJ-S-01...
# 30              /leaf/Piper Betle (Betel)/PB-S-027.jpg
# ..                                                 ...
# 16           /leaf/Hibiscus Rosa-sinensis/HR-S-012.jpg
# 52         /leaf/Mangifera Indica (Mango)/MI-S-001.jpg
# 45       /leaf/Ocimum Tenuiflorum (Tulsi)/OT-S-021.jpg
# 24   /leaf/Pongamia Pinnata (Indian Beech)/PP-S-011...
# 13          /leaf/Alpinia Galanga (Rasna)/AG-S-016.jpg
#
#                                    types
# 42              Murraya Koenigii (Curry)
# 11   Nyctanthes Arbor-tristis (Parijata)
# 100     Amaranthus Viridis (Arive-Dantu)
# 28      Brassica Juncea (Indian Mustard)
# 30                   Piper Betle (Betel)
# ..                                   ...
# 16                Hibiscus Rosa-sinensis
# 52              Mangifera Indica (Mango)
# 45            Ocimum Tenuiflorum (Tulsi)
# 24       Pongamia Pinnata (Indian Beech)
# 13               Alpinia Galanga (Rasna)
#
# [367 rows x 2 columns]

# %%
Y_train
# Out:
# 40         Murraya Koenigii (Curry)
# 47         Mangifera Indica (Mango)
# 20          Syzygium Cumini (Jamun)
# 42      Santalum Album (Sandalwood)
# 23              Piper Betle (Betel)
#                   ...
# 24            Basella Alba (Basale)
# 31           Hibiscus Rosa-sinensis
# 43         Mangifera Indica (Mango)
# 35               Jasminum (Jasmine)
# 19    Ficus Religiosa (Peepal Tree)
# Name: types, Length: 1101, dtype: object

# %%
Y_test
# Out:
# 42                Murraya Koenigii (Curry)
# 11     Nyctanthes Arbor-tristis (Parijata)
# 100       Amaranthus Viridis (Arive-Dantu)
# 28        Brassica Juncea (Indian Mustard)
# 30                     Piper Betle (Betel)
#                       ...
# 16                  Hibiscus Rosa-sinensis
# 52                Mangifera Indica (Mango)
# 45              Ocimum Tenuiflorum (Tulsi)
# 24         Pongamia Pinnata (Indian Beech)
# 13                 Alpinia Galanga (Rasna)
# Name: types, Length: 367, dtype: object

# %%
X_val
# Out:
#                                            filepath  \
# 4              /leaf/Jasminum (Jasmine)/J-S-068.jpg
# 59  /leaf/Moringa Oleifera (Drumstick)/MO-S-016.jpg
# 5     /leaf/Carissa Carandas (Karanda)/CC-S-060.jpg
# 45          /leaf/Citrus Limon (Lemon)/CL-S-010.jpg
# 0     /leaf/Ocimum Tenuiflorum (Tulsi)/OT-S-048.jpg
# ..                                              ...
# 12  /leaf/Moringa Oleifera (Drumstick)/MO-S-072.jpg
# 75         /leaf/Basella Alba (Basale)/BA-S-006.jpg
# 49       /leaf/Psidium Guajava (Guava)/PG-S-008.jpg
# 22       /leaf/Alpinia Galanga (Rasna)/AG-S-011.jpg
# 33    /leaf/Ocimum Tenuiflorum (Tulsi)/OT-S-035.jpg
#
#                            types
# 4             Jasminum (Jasmine)
# 59  Moringa Oleifera (Drumstick)
# 5     Carissa Carandas (Karanda)
# 45          Citrus Limon (Lemon)
# 0     Ocimum Tenuiflorum (Tulsi)
# ..                           ...
# 12  Moringa Oleifera (Drumstick)
# 75         Basella Alba (Basale)
# 49       Psidium Guajava (Guava)
# 22       Alpinia Galanga (Rasna)
# 33    Ocimum Tenuiflorum (Tulsi)
#
# [367 rows x 2 columns]

# %%
Y_val
# Out:
# 4               Jasminum (Jasmine)
# 59    Moringa Oleifera (Drumstick)
# 5       Carissa Carandas (Karanda)
# 45            Citrus Limon (Lemon)
# 0       Ocimum Tenuiflorum (Tulsi)
#                   ...
# 12    Moringa Oleifera (Drumstick)
# 75           Basella Alba (Basale)
# 49         Psidium Guajava (Guava)
# 22         Alpinia Galanga (Rasna)
# 33      Ocimum Tenuiflorum (Tulsi)
# Name: types, Length: 367, dtype: object

# %%
X_train['use'] = 'train'
X_val['use'] = 'val'
X_test['use'] = 'test'

# %%
fulldf = pd.concat([ X_train, X_test, X_val ])

# %%
fulldf.use.value_counts()
# Out:
# train    1101
# test      367
# val       367
# Name: use, dtype: int64

# %% [markdown]
# #### Final DATFRAME

# %%
fulldf.head(20)
# Out:
#                                              filepath  \
# 40        /leaf/Murraya Koenigii (Curry)/MK-S-040.jpg
# 47        /leaf/Mangifera Indica (Mango)/MI-S-057.jpg
# 20         /leaf/Syzygium Cumini (Jamun)/SC-S-026.jpg
# 42     /leaf/Santalum Album (Sandalwood)/SA-S-048.jpg
# 23             /leaf/Piper Betle (Betel)/PB-S-034.jpg
# 10         /leaf/Syzygium Cumini (Jamun)/SC-S-007.jpg
# 28    /leaf/Moringa Oleifera (Drumstick)/MO-S-007.jpg
# 60    /leaf/Moringa Oleifera (Drumstick)/MO-S-069.jpg
# 31  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-00...
# 89  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-06...
# 28  /leaf/Muntingia Calabura (Jamaica Cherry-Gasag...
# 45    /leaf/Moringa Oleifera (Drumstick)/MO-S-020.jpg
# 62      /leaf/Carissa Carandas (Karanda)/CC-S-027.jpg
# 12             /leaf/Piper Betle (Betel)/PB-S-006.jpg
# 44            /leaf/Citrus Limon (Lemon)/CL-S-039.jpg
# 20  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-03...
# 27      /leaf/Carissa Carandas (Karanda)/CC-S-032.jpg
# 30  /leaf/Pongamia Pinnata (Indian Beech)/PP-S-034...
# 3   /leaf/Trigonella Foenum-graecum (Fenugreek)/TF...
# 57  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-07...
#
#                                            types    use
# 40                      Murraya Koenigii (Curry)  train
# 47                      Mangifera Indica (Mango)  train
# 20                       Syzygium Cumini (Jamun)  train
# 42                   Santalum Album (Sandalwood)  train
# 23                           Piper Betle (Betel)  train
# 10                       Syzygium Cumini (Jamun)  train
# 28                  Moringa Oleifera (Drumstick)  train
# 60                  Moringa Oleifera (Drumstick)  train
# 31              Amaranthus Viridis (Arive-Dantu)  train
# 89              Amaranthus Viridis (Arive-Dantu)  train
# 28  Muntingia Calabura (Jamaica Cherry-Gasagase)  train
# 45                  Moringa Oleifera (Drumstick)  train
# 62                    Carissa Carandas (Karanda)  train
# 12                           Piper Betle (Betel)  train
# 44                          Citrus Limon (Lemon)  train
# 20              Amaranthus Viridis (Arive-Dantu)  train
# 27                    Carissa Carandas (Karanda)  train
# 30               Pongamia Pinnata (Indian Beech)  train
# 3          Trigonella Foenum-graecum (Fenugreek)  train
# 57              Amaranthus Viridis (Arive-Dantu)  train

# %% [markdown]
# ##### BASELINE ACCURACY

# %%
fulldf.types.value_counts()[0] / len( fulldf ) ## basically which sample dominates
# Out:
# 0.0664850136239782

# %% [markdown]
# ### **Creating Train, Test, Validation Folders**

# %%
# !mkdir data
# !rm -rf data/
# !rm -rf data/train
# !rm -rf data/test
# !rm -rf data/val
# !mkdir data/
# !mkdir data/train
# !mkdir data/test
# !mkdir data/val

# %%
fulldf.types.unique()
# Out:
# array(['Murraya Koenigii (Curry)', 'Mangifera Indica (Mango)',
#        'Syzygium Cumini (Jamun)', 'Santalum Album (Sandalwood)',
#        'Piper Betle (Betel)', 'Moringa Oleifera (Drumstick)',
#        'Amaranthus Viridis (Arive-Dantu)',
#        'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#        'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)',
#        'Pongamia Pinnata (Indian Beech)',
#        'Trigonella Foenum-graecum (Fenugreek)',
#        'Syzygium Jambos (Rose Apple)', 'Psidium Guajava (Guava)',
#        'Brassica Juncea (Indian Mustard)', 'Alpinia Galanga (Rasna)',
#        'Azadirachta Indica (Neem)',
#        'Plectranthus Amboinicus (Mexican Mint)', 'Basella Alba (Basale)',
#        'Nyctanthes Arbor-tristis (Parijata)',
#        'Ficus Auriculata (Roxburgh fig)', 'Jasminum (Jasmine)',
#        'Mentha (Mint)', 'Nerium Oleander (Oleander)',
#        'Hibiscus Rosa-sinensis', 'Ficus Religiosa (Peepal Tree)',
#        'Tabernaemontana Divaricata (Crape Jasmine)',
#        'Ocimum Tenuiflorum (Tulsi)',
#        'Artocarpus Heterophyllus (Jackfruit)',
#        'Punica Granatum (Pomegranate)'], dtype=object)

# %%
for typ in fulldf.types.unique():
    os.system(f"mkdir data/train/'{typ}'")
    os.system(f"mkdir data/test/'{typ}'")
    os.system(f"mkdir data/val/'{typ}'")

# %%
fulldf.head()
# Out:
#                                           filepath  \
# 40     /leaf/Murraya Koenigii (Curry)/MK-S-040.jpg
# 47     /leaf/Mangifera Indica (Mango)/MI-S-057.jpg
# 20      /leaf/Syzygium Cumini (Jamun)/SC-S-026.jpg
# 42  /leaf/Santalum Album (Sandalwood)/SA-S-048.jpg
# 23          /leaf/Piper Betle (Betel)/PB-S-034.jpg
#
#                           types    use
# 40     Murraya Koenigii (Curry)  train
# 47     Mangifera Indica (Mango)  train
# 20      Syzygium Cumini (Jamun)  train
# 42  Santalum Album (Sandalwood)  train
# 23          Piper Betle (Betel)  train

# %%
for i, row in fulldf.iterrows():

    # plant category
    typ = row['types']

    # section is train,val or test
    section = row['use']

    # input filepath to copy
    ipath = row['filepath']

    # output filepath to paste
    opath = ipath.replace(f"/leaf/",f"data/{section}/")


    # running the cp command
    os.system(f"cp '{ipath}' '{opath}'")

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Transforms**
# In order to use our images with a network trained on the Imagenet dataset, we need to preprocess our images in the same way as the Imagenet network. For that, we need to rescale the images to 224×224 and normalize them as per Imagenet standards. We can use the torchvision transforms library to do that. Here we take a CenterCrop of 224×224 and normalize as per Imagenet standards.

# %% [markdown]
# # **PLANT MODEL**

# %%
import torch
from collections import Counter
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
import os
from glob import glob
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import models
import torch.nn as nn

from torchvision import transforms, datasets, models
import torch
from torch import optim, cuda
from torch.utils.data import DataLoader, sampler
import torch.nn as nn
import numpy as np
import tqdm

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Data science tools
import numpy as np
import pandas as pd
import os

# Image manipulations
from PIL import Image

from timeit import default_timer as timer

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 14

# %%
from torch import Tensor, nn
from torch.nn.functional import interpolate

# %%
def imshow_tensor(image, ax=None, title=None):
    """Imshow for Tensor."""

    if ax is None:
        fig, ax = plt.subplots()

    # Set the color channel as the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Reverse the preprocessing steps
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Clip the image pixel values
    image = np.clip(image, 0, 1)

    ax.imshow(image)
    plt.axis('off')

    return ax, image

# %%
traindir = f"data/train"
validdir = f"data/val"
testdir = f"data/test"

# %%
os.listdir('data/train/')
# Out:
# ['Jasminum (Jasmine)',
#  'Nyctanthes Arbor-tristis (Parijata)',
#  'Azadirachta Indica (Neem)',
#  'Ficus Auriculata (Roxburgh fig)',
#  'Tabernaemontana Divaricata (Crape Jasmine)',
#  'Nerium Oleander (Oleander)',
#  'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#  'Alpinia Galanga (Rasna)',
#  'Citrus Limon (Lemon)',
#  'Mangifera Indica (Mango)',
#  'Ficus Religiosa (Peepal Tree)',
#  'Ocimum Tenuiflorum (Tulsi)',
#  'Brassica Juncea (Indian Mustard)',
#  'Santalum Album (Sandalwood)',
#  'Amaranthus Viridis (Arive-Dantu)',
#  'Psidium Guajava (Guava)',
#  'Basella Alba (Basale)',
#  'Carissa Carandas (Karanda)',
#  'Syzygium Jambos (Rose Apple)',
#  'Pongamia Pinnata (Indian Beech)',
#  'Murraya Koenigii (Curry)',
#  'Piper Betle (Betel)',
#  'Punica Granatum (Pomegranate)',
#  'Syzygium Cumini (Jamun)',
#  'Moringa Oleifera (Drumstick)',
#  'Artocarpus Heterophyllus (Jackfruit)',
#  'Trigonella Foenum-graecum (Fenugreek)',
#  'Plectranthus Amboinicus (Mexican Mint)',
#  'Hibiscus Rosa-sinensis',
#  'Mentha (Mint)']

# %%
save_file_name = f'resnet50-transfer.pt'
checkpoint_path = f'resnet50-transfer.pth'

# Change to fit hardware
batch_size = 512
###### MINE
multi_gpu = False
# Whether to train on a gpu
train_on_gpu = cuda.is_available()
print(f'Train on gpu: {train_on_gpu}')

# Number of gpus
if train_on_gpu:
    gpu_count = cuda.device_count()
    print(f'{gpu_count} gpus detected.')
    if gpu_count > 1:
        multi_gpu = True
    else:
        multi_gpu = False
print(train_on_gpu,multi_gpu)
# Out:
# Train on gpu: True
# 1 gpus detected.
# True False

# %%
image_transforms = {
    # Train uses data augmentation
    'train':
    transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])  # Imagenet standards
    ]),
    # Validation does not use augmentation
    'valid':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

        # Test does not use augmentation
    'test':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
ex_img = Image.open('/content/data/train/Piper Betle (Betel)/PB-S-002.jpg')

t = image_transforms['train']
plt.figure(figsize=(10, 10))

for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    _ = imshow_tensor(t(ex_img), ax=ax)

plt.tight_layout()

# %% [markdown]
# # **DATALOADER**

# %%
# Datasets from folders
data = {
    'train':
    datasets.ImageFolder( root = traindir, transform = image_transforms['train'] ),
    'valid':
    datasets.ImageFolder( root = validdir, transform = image_transforms['valid']),
    'test':
    datasets.ImageFolder( root = testdir, transform = image_transforms['test'])
}

# Dataloader iterators, make sure to shuffle
dataloaders = {
    'train': DataLoader( data['train'], batch_size = batch_size, shuffle = True, num_workers = 0 ),
    'val': DataLoader( data['valid'], batch_size = batch_size, shuffle = True, num_workers = 0),
    'test': DataLoader( data['test'], batch_size = batch_size, shuffle = True, num_workers= 0)
}

# %%
# Iterate through the dataloader once
trainiter = iter(dataloaders['train'])
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([512, 3, 224, 224]), torch.Size([512]))

# %%
categories = []
for d in os.listdir(traindir):
    categories.append(d)

n_classes = len(categories)
print(f'There are {n_classes} different classes.')
# Out:
# There are 30 different classes.

# %% [markdown]
# # **Some Statistics**

# %%
class_to_idx = data['train'].class_to_idx
idx_to_class = {
    idx: class_
    for class_, idx in data['train'].class_to_idx.items()
}

# %%
train_cnts = Counter([idx_to_class[x] for x in data['train'].targets])
val_cnts = Counter([idx_to_class[x] for x in data['valid'].targets])
test_cnts = Counter([idx_to_class[x] for x in data['test'].targets])

# %%
train_cnts = pd.DataFrame({'cat' :list(train_cnts.keys()), 'train_cnt': list(train_cnts.values())})
val_cnts = pd.DataFrame({'cat' :list(val_cnts.keys()), 'val_cnt': list(val_cnts.values())})
test_cnts = pd.DataFrame({'cat' :list(test_cnts.keys()), 'test_cnt': list(test_cnts.values())})

# %%
cnt_df = pd.merge(train_cnts,val_cnts,on='cat',how='left').merge(test_cnts,on='cat',how='left')

# %%
cnt_df.head()
# Out:
#                                     cat  train_cnt  val_cnt  test_cnt
# 0               Alpinia Galanga (Rasna)         30       10        10
# 1      Amaranthus Viridis (Arive-Dantu)         73       25        24
# 2  Artocarpus Heterophyllus (Jackfruit)         33       12        11
# 3             Azadirachta Indica (Neem)         36       12        12
# 4                 Basella Alba (Basale)         62       20        21

# %%
idx_to_class
# Out:
# {0: 'Alpinia Galanga (Rasna)',
#  1: 'Amaranthus Viridis (Arive-Dantu)',
#  2: 'Artocarpus Heterophyllus (Jackfruit)',
#  3: 'Azadirachta Indica (Neem)',
#  4: 'Basella Alba (Basale)',
#  5: 'Brassica Juncea (Indian Mustard)',
#  6: 'Carissa Carandas (Karanda)',
#  7: 'Citrus Limon (Lemon)',
#  8: 'Ficus Auriculata (Roxburgh fig)',
#  9: 'Ficus Religiosa (Peepal Tree)',
#  10: 'Hibiscus Rosa-sinensis',
#  11: 'Jasminum (Jasmine)',
#  12: 'Mangifera Indica (Mango)',
#  13: 'Mentha (Mint)',
#  14: 'Moringa Oleifera (Drumstick)',
#  15: 'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#  16: 'Murraya Koenigii (Curry)',
#  17: 'Nerium Oleander (Oleander)',
#  18: 'Nyctanthes Arbor-tristis (Parijata)',
#  19: 'Ocimum Tenuiflorum (Tulsi)',
#  20: 'Piper Betle (Betel)',
#  21: 'Plectranthus Amboinicus (Mexican Mint)',
#  22: 'Pongamia Pinnata (Indian Beech)',
#  23: 'Psidium Guajava (Guava)',
#  24: 'Punica Granatum (Pomegranate)',
#  25: 'Santalum Album (Sandalwood)',
#  26: 'Syzygium Cumini (Jamun)',
#  27: 'Syzygium Jambos (Rose Apple)',
#  28: 'Tabernaemontana Divaricata (Crape Jasmine)',
#  29: 'Trigonella Foenum-graecum (Fenugreek)'}

# %% [markdown]
# # **MODELS**

# %%
model = models.resnet50( weights = 'DEFAULT' )
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 76.1MB/s]

# %%
# Freeze model weights
for param in model.parameters():
    param.requires_grad = False

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
n_inputs = model.fc.in_features

# %%
model.fc = nn.Sequential(
                      nn.Linear(n_inputs, 256),
                      nn.ReLU(),
                      nn.Dropout(0.4),
                      nn.Linear(256, n_classes),
                      nn.LogSoftmax(dim=1))

# %%
model.fc
# Out:
# Sequential(
#   (0): Linear(in_features=2048, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4, inplace=False)
#   (3): Linear(in_features=256, out_features=30, bias=True)
#   (4): LogSoftmax(dim=1)
# )

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 24,040,286 total parameters.
# 532,254 training parameters.

# %%
if train_on_gpu:
    model = model.to('cuda')

if multi_gpu:
    model = nn.DataParallel(model)

# %%
if multi_gpu:
    print(model.module.fc)
else:
    print(model.fc)
# Out:
# Sequential(
#   (0): Linear(in_features=2048, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4, inplace=False)
#   (3): Linear(in_features=256, out_features=30, bias=True)
#   (4): LogSoftmax(dim=1)
# )

# %%
model.class_to_idx = data['train'].class_to_idx
model.idx_to_class = {
    idx: class_
    for class_, idx in model.class_to_idx.items()
}

list(model.idx_to_class.items())
# Out:
# [(0, 'Alpinia Galanga (Rasna)'),
#  (1, 'Amaranthus Viridis (Arive-Dantu)'),
#  (2, 'Artocarpus Heterophyllus (Jackfruit)'),
#  (3, 'Azadirachta Indica (Neem)'),
#  (4, 'Basella Alba (Basale)'),
#  (5, 'Brassica Juncea (Indian Mustard)'),
#  (6, 'Carissa Carandas (Karanda)'),
#  (7, 'Citrus Limon (Lemon)'),
#  (8, 'Ficus Auriculata (Roxburgh fig)'),
#  (9, 'Ficus Religiosa (Peepal Tree)'),
#  (10, 'Hibiscus Rosa-sinensis'),
#  (11, 'Jasminum (Jasmine)'),
#  (12, 'Mangifera Indica (Mango)'),
#  (13, 'Mentha (Mint)'),
#  (14, 'Moringa Oleifera (Drumstick)'),
#  (15, 'Muntingia Calabura (Jamaica Cherry-Gasagase)'),
#  (16, 'Murraya Koenigii (Curry)'),
#  (17, 'Nerium Oleander (Oleander)'),
#  (18, 'Nyctanthes Arbor-tristis (Parijata)'),
#  (19, 'Ocimum Tenuiflorum (Tulsi)'),
#  (20, 'Piper Betle (Betel)'),
#  (21, 'Plectranthus Amboinicus (Mexican Mint)'),
#  (22, 'Pongamia Pinnata (Indian Beech)'),
#  (23, 'Psidium Guajava (Guava)'),
#  (24, 'Punica Granatum (Pomegranate)'),
#  (25, 'Santalum Album (Sandalwood)'),
#  (26, 'Syzygium Cumini (Jamun)'),
#  (27, 'Syzygium Jambos (Rose Apple)'),
#  (28, 'Tabernaemontana Divaricata (Crape Jasmine)'),
#  (29, 'Trigonella Foenum-graecum (Fenugreek)')]

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters())

# %%
for p in optimizer.param_groups[0]['params']:
    if p.requires_grad:
        print(p.shape)
# Out:
# torch.Size([256, 2048])
# torch.Size([256])
# torch.Size([30, 256])
# torch.Size([30])

# %%
def train(model,
          criterion,
          optimizer,
          train_loader,
          valid_loader,
          save_file_name,
          max_epochs_stop=3,
          n_epochs=20,
          print_every=1):
    """Train a PyTorch Model

    Params
    --------
        model (PyTorch model): cnn to train
        criterion (PyTorch loss): objective to minimize
        optimizer (PyTorch optimizier): optimizer to compute gradients of model parameters
        train_loader (PyTorch dataloader): training dataloader to iterate through
        valid_loader (PyTorch dataloader): validation dataloader used for early stopping
        save_file_name (str ending in '.pt'): file path to save the model state dict
        max_epochs_stop (int): maximum number of epochs with no improvement in validation loss for early stopping
        n_epochs (int): maximum number of training epochs
        print_every (int): frequency of epochs to print training stats

    Returns
    --------
        model (PyTorch model): trained cnn with best weights
        history (DataFrame): history of train and validation loss and accuracy
    """

    # Early stopping intialization
    epochs_no_improve = 0
    valid_loss_min = np.Inf

    valid_max_acc = 0
    history = []

    # Number of epochs already trained (if using loaded in model weights)
    try:
        print(f'Model has been trained for: {model.epochs} epochs.\n')
    except:
        model.epochs = 0
        print(f'Starting Training from Scratch.\n')

    overall_start = timer()

    # Main loop
    for epoch in range(n_epochs):

        # keep track of training and validation loss each epoch
        train_loss = 0.0
        valid_loss = 0.0

        train_acc = 0
        valid_acc = 0

        # Set to training
        model.train()
        start = timer()

        # Training loop
        for ii, (data, target) in enumerate(train_loader):
            # Tensors to gpu
            if train_on_gpu:
                data, target = data.cuda(), target.cuda()

            # Clear gradients
            optimizer.zero_grad()

            # Predicted outputs are log probabilities
            output = model(data)

            # Loss and backpropagation of gradients
            loss = criterion(output, target)
            loss.backward()

            # Update the parameters
            optimizer.step()

            # Track train loss by multiplying average loss by number of examples in batch
            train_loss += loss.item() * data.size(0)

            # Calculate accuracy by finding max log probability
            _, pred = torch.max(output, dim=1)
            correct_tensor = pred.eq(target.data.view_as(pred))

            # Need to convert correct tensor from int to float to average
            accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))

            # Multiply average accuracy times the number of examples in batch
            train_acc += accuracy.item() * data.size(0)

            # Track training progress
            print(
                f'Epoch: {epoch}\t{100 * (ii + 1) / len(train_loader):.2f}% complete. {timer() - start:.2f} seconds elapsed in epoch.',
                end='\r')

        # After training loops ends, start validation
        else:
            model.epochs += 1

            # Don't need to keep track of gradients
            with torch.no_grad():
                # Set to evaluation mode
                model.eval()

                # Validation loop
                for data, target in valid_loader:
                    # Tensors to gpu
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()

                    # Forward pass
                    output = model(data)

                    # Validation loss
                    loss = criterion(output, target)
                    # Multiply average loss times the number of examples in batch
                    valid_loss += loss.item() * data.size(0)

                    # Calculate validation accuracy
                    _, pred = torch.max(output, dim=1)
                    correct_tensor = pred.eq(target.data.view_as(pred))
                    accuracy = torch.mean(
                        correct_tensor.type(torch.FloatTensor))
                    # Multiply average accuracy times the number of examples
                    valid_acc += accuracy.item() * data.size(0)

                # Calculate average losses
                train_loss = train_loss / len(train_loader.dataset)
                valid_loss = valid_loss / len(valid_loader.dataset)

                # Calculate average accuracy
                train_acc = train_acc / len(train_loader.dataset)
                valid_acc = valid_acc / len(valid_loader.dataset)

                history.append([train_loss, valid_loss, train_acc, valid_acc])

                # Print training and validation results
                if (epoch + 1) % print_every == 0:
                    print(
                        f'\nEpoch: {epoch} \tTraining Loss: {train_loss:.4f}        \tValidation Loss: {valid_loss:.4f}'
                    )
                    print(
                        f'\t\tTraining Accuracy: {100 * train_acc:.2f}%\t Validation Accuracy: {100 * valid_acc:.2f}%'
                    )

                # Save the model if validation loss decreases
                if valid_loss < valid_loss_min:
                    # Save model
                    torch.save(model.state_dict(), save_file_name)
                    # Track improvement
                    epochs_no_improve = 0
                    valid_loss_min = valid_loss
                    valid_best_acc = valid_acc
                    best_epoch = epoch

                # Otherwise increment count of epochs with no improvement
                else:
                    epochs_no_improve += 1
                    # Trigger early stopping
                    if epochs_no_improve >= max_epochs_stop:
                        print(
                            f'\nEarly Stopping! Total epochs: {epoch}. Best epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
                        )
                        total_time = timer() - overall_start
                        print(
                            f'{total_time:.2f} total seconds elapsed. {total_time / (epoch+1):.2f} seconds per epoch.'
                        )

                        # Load the best state dict
                        model.load_state_dict(torch.load(save_file_name))

                        # Attach the optimizer
                        model.optimizer = optimizer

                        # Format history
                        history = pd.DataFrame(
                            history,
                            columns=[
                                'train_loss', 'valid_loss', 'train_acc',
                                'valid_acc'
                            ])
                        return model, history

    # Attach the optimizer
    model.optimizer = optimizer
    # Record overall time and print out stats
    total_time = timer() - overall_start
    print(
        f'\nBest epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
    )
    print(
        f'{total_time:.2f} total seconds elapsed. {total_time / (epoch):.2f} seconds per epoch.'
    )
    # Format history
    history = pd.DataFrame(
        history,
        columns=['train_loss', 'valid_loss', 'train_acc', 'valid_acc'])
    return model, history

# %%
model, history = train(
    model,
    criterion,
    optimizer,
    dataloaders['train'],
    dataloaders['val'],
    save_file_name=save_file_name,
    max_epochs_stop=3,
    n_epochs=100,
    print_every=1)
# Out:
# Starting Training from Scratch.
#
#
# Epoch: 0 	Training Loss: 3.3560        	Validation Loss: 3.3219
# 		Training Accuracy: 10.90%	 Validation Accuracy: 18.26%
#
# Epoch: 1 	Training Loss: 3.0402        	Validation Loss: 3.1644
# 		Training Accuracy: 37.33%	 Validation Accuracy: 25.61%
#
# Epoch: 2 	Training Loss: 2.7044        	Validation Loss: 2.8992
# 		Training Accuracy: 47.14%	 Validation Accuracy: 46.05%
#
# Epoch: 3 	Training Loss: 2.3890        	Validation Loss: 2.5585
# 		Training Accuracy: 57.22%	 Validation Accuracy: 59.40%
#
# Epoch: 4 	Training Loss: 2.0562        	Validation Loss: 2.1908
# 		Training Accuracy: 67.85%	 Validation Accuracy: 70.30%
#
# Epoch: 5 	Training Loss: 1.7508        	Validation Loss: 1.8497
# 		Training Accuracy: 76.02%	 Validation Accuracy: 77.11%
#
# Epoch: 6 	Training Loss: 1.4826        	Validation Loss: 1.5551
# 		Training Accuracy: 80.84%	 Validation Accuracy: 80.93%
#
# Epoch: 7 	Training Loss: 1.2525        	Validation Loss: 1.2855
# 		Training Accuracy: 83.11%	 Validation Accuracy: 88.01%
#
# Epoch: 8 	Training Loss: 1.0539        	Validation Loss: 1.0619
# 		Training Accuracy: 85.38%	 Validation Accuracy: 90.74%
#
# Epoch: 9 	Training Loss: 0.8704        	Validation Loss: 0.8971
# 		Training Accuracy: 88.28%	 Validation Accuracy: 90.46%
#
# Epoch: 10 	Training Loss: 0.7488        	Validation Loss: 0.7675
# 		Training Accuracy: 90.83%	 Validation Accuracy: 92.92%
#
# Epoch: 11 	Training Loss: 0.6307        	Validation Loss: 0.6426
# 		Training Accuracy: 92.28%	 Validation Accuracy: 93.46%
#
# Epoch: 12 	Training Loss: 0.5552        	Validation Loss: 0.5518
# 		Training Accuracy: 91.55%	 Validation Accuracy: 94.55%
#
# Epoch: 13 	Training Loss: 0.4715        	Validation Loss: 0.4860
# 		Training Accuracy: 94.82%	 Validation Accuracy: 96.46%
#
# Epoch: 14 	Training Loss: 0.4386        	Validation Loss: 0.4399
# 		Training Accuracy: 94.19%	 Validation Accuracy: 95.64%
#
# Epoch: 15 	Training Loss: 0.3766        	Validation Loss: 0.3843
# 		Training Accuracy: 95.28%	 Validation Accuracy: 96.46%
#
# Epoch: 16 	Training Loss: 0.3491        	Validation Loss: 0.3407
# 		Training Accuracy: 95.46%	 Validation Accuracy: 97.28%
#
# Epoch: 17 	Training Loss: 0.2959        	Validation Loss: 0.3128
# 		Training Accuracy: 95.64%	 Validation Accuracy: 97.28%
#
# Epoch: 18 	Training Loss: 0.2884        	Validation Loss: 0.3020
# 		Training Accuracy: 95.73%	 Validation Accuracy: 96.46%
#
# Epoch: 19 	Training Loss: 0.2579        	Validation Loss: 0.2911
# 		Training Accuracy: 96.73%	 Validation Accuracy: 97.28%
#
# Epoch: 20 	Training Loss: 0.2489        	Validation Loss: 0.2642
# 		Training Accuracy: 95.64%	 Validation Accuracy: 97.55%
#
# Epoch: 21 	Training Loss: 0.2218        	Validation Loss: 0.2364
# 		Training Accuracy: 97.28%	 Validation Accuracy: 97.55%
#
# Epoch: 22 	Training Loss: 0.2218        	Validation Loss: 0.2144
# 		Training Accuracy: 96.91%	 Validation Accuracy: 97.82%
#
# Epoch: 23 	Training Loss: 0.1809        	Validation Loss: 0.1999
# 		Training Accuracy: 98.00%	 Validation Accuracy: 97.82%
#
# Epoch: 24 	Training Loss: 0.1798        	Validation Loss: 0.1931
# 		Training Accuracy: 98.00%	 Validation Accuracy: 98.09%
#
# Epoch: 25 	Training Loss: 0.1658        	Validation Loss: 0.1960
# 		Training Accuracy: 97.64%	 Validation Accuracy: 97.55%
#
# Epoch: 26 	Training Loss: 0.1701        	Validation Loss: 0.1883
# 		Training Accuracy: 97.73%	 Validation Accuracy: 97.82%
#
# Epoch: 27 	Training Loss: 0.1531        	Validation Loss: 0.1786
# 		Training Accuracy: 97.55%	 Validation Accuracy: 98.09%
#
# Epoch: 28 	Training Loss: 0.1454        	Validation Loss: 0.1575
# 		Training Accuracy: 97.91%	 Validation Accuracy: 98.37%
#
# Epoch: 29 	Training Loss: 0.1380        	Validation Loss: 0.1442
# 		Training Accuracy: 98.37%	 Validation Accuracy: 98.64%
#
# Epoch: 30 	Training Loss: 0.1493        	Validation Loss: 0.1364
# 		Training Accuracy: 97.37%	 Validation Accuracy: 98.91%
#
# Epoch: 31 	Training Loss: 0.1286        	Validation Loss: 0.1314
# 		Training Accuracy: 98.27%	 Validation Accuracy: 98.64%
#
# Epoch: 32 	Training Loss: 0.1220        	Validation Loss: 0.1282
# 		Training Accuracy: 97.82%	 Validation Accuracy: 98.09%
#
# Epoch: 33 	Training Loss: 0.1119        	Validation Loss: 0.1283
# 		Training Accuracy: 98.27%	 Validation Accuracy: 98.37%
#
# Epoch: 34 	Training Loss: 0.1150        	Validation Loss: 0.1267
# 		Training Accuracy: 98.37%	 Validation Accuracy: 98.64%
#
# Epoch: 35 	Training Loss: 0.1073        	Validation Loss: 0.1256
# 		Training Accuracy: 98.55%	 Validation Accuracy: 98.64%
#
# Epoch: 36 	Training Loss: 0.1012        	Validation Loss: 0.1191
# 		Training Accuracy: 99.09%	 Validation Accuracy: 98.09%
#
# Epoch: 37 	Training Loss: 0.0962        	Validation Loss: 0.1148
# 		Training Accuracy: 99.18%	 Validation Accuracy: 98.09%
#
# Epoch: 38 	Training Loss: 0.0943        	Validation Loss: 0.1074
# 		Training Accuracy: 98.73%	 Validation Accuracy: 98.64%
#
# Epoch: 39 	Training Loss: 0.0910        	Validation Loss: 0.1002
# 		Training Accuracy: 98.73%	 Validation Accuracy: 98.91%
#
# Epoch: 40 	Training Loss: 0.0866        	Validation Loss: 0.0992
# 		Training Accuracy: 99.00%	 Validation Accuracy: 98.91%
#
# Epoch: 41 	Training Loss: 0.0790        	Validation Loss: 0.0958
# 		Training Accuracy: 99.18%	 Validation Accuracy: 98.64%
#
# Epoch: 42 	Training Loss: 0.0871        	Validation Loss: 0.0944
# 		Training Accuracy: 98.73%	 Validation Accuracy: 98.64%
#
# Epoch: 43 	Training Loss: 0.0809        	Validation Loss: 0.0934
# 		Training Accuracy: 99.09%	 Validation Accuracy: 99.18%
#
# Epoch: 44 	Training Loss: 0.0820        	Validation Loss: 0.0931
# 		Training Accuracy: 99.09%	 Validation Accuracy: 98.91%
#
# Epoch: 45 	Training Loss: 0.0837        	Validation Loss: 0.0957
# 		Training Accuracy: 98.91%	 Validation Accuracy: 98.64%
#
# Epoch: 46 	Training Loss: 0.0763        	Validation Loss: 0.0961
# 		Training Accuracy: 99.18%	 Validation Accuracy: 98.64%
#
# Epoch: 47 	Training Loss: 0.0677        	Validation Loss: 0.0915
# 		Training Accuracy: 99.27%	 Validation Accuracy: 98.91%
#
# Epoch: 48 	Training Loss: 0.0629        	Validation Loss: 0.0845
# 		Training Accuracy: 99.27%	 Validation Accuracy: 99.18%
#
# Epoch: 49 	Training Loss: 0.0620        	Validation Loss: 0.0802
# 		Training Accuracy: 99.18%	 Validation Accuracy: 98.64%
#
# Epoch: 50 	Training Loss: 0.0644        	Validation Loss: 0.0778
# 		Training Accuracy: 99.27%	 Validation Accuracy: 98.91%
#
# Epoch: 51 	Training Loss: 0.0579        	Validation Loss: 0.0755
# 		Training Accuracy: 99.27%	 Validation Accuracy: 98.91%
#
# Epoch: 52 	Training Loss: 0.0617        	Validation Loss: 0.0732
# 		Training Accuracy: 99.27%	 Validation Accuracy: 98.91%
#
# Epoch: 53 	Training Loss: 0.0708        	Validation Loss: 0.0715
# 		Training Accuracy: 98.73%	 Validation Accuracy: 98.64%
#
# Epoch: 54 	Training Loss: 0.0667        	Validation Loss: 0.0729
# 		Training Accuracy: 99.27%	 Validation Accuracy: 98.91%
#
# Epoch: 55 	Training Loss: 0.0550        	Validation Loss: 0.0730
# 		Training Accuracy: 99.36%	 Validation Accuracy: 98.91%
#
# Epoch: 56 	Training Loss: 0.0608        	Validation Loss: 0.0716
# 		Training Accuracy: 99.36%	 Validation Accuracy: 99.46%
#
# Early Stopping! Total epochs: 56. Best epoch: 53 with loss: 0.07 and acc: 99.46%
# 2038.02 total seconds elapsed. 35.75 seconds per epoch.

# %% [markdown]
# # **Results**

# %%
plt.figure(figsize=(8, 6))
for c in ['train_loss', 'valid_loss']:
    plt.plot(
        history[c], label=c)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Negative Log Likelihood')
plt.title('Training and Validation Losses')
# Out:
# Text(0.5, 1.0, 'Training and Validation Losses')

# %%
plt.figure(figsize = (8, 6))

for c in ['train_acc', 'valid_acc']:
    plt.plot(100 * history[c], label = c)

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Accuracy')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %% [markdown]
# # **Save Model**

# %%
def save_checkpoint(model, path):

    """Save a PyTorch model checkpoint

    Params
    --------
        model (PyTorch model): model to save
        path (str): location to save model. Must start with `model_name-` and end in '.pth'

    Returns
    --------
        None, save the `model` to `path`

    """

    model_name = path.split('-')[0]
    assert (model_name in ['vgg16', 'resnet50'
                           ]), "Path must have the correct model name"

    # Basic details
    checkpoint = {
        'class_to_idx': model.class_to_idx,
        'idx_to_class': model.idx_to_class,
        'epochs': model.epochs,
    }

    # Extract the final classifier and the state dictionary

    if model_name == 'vgg16':

        # Check to see if model was parallelized
        if multi_gpu:
            checkpoint['classifier'] = model.module.classifier
            checkpoint['state_dict'] = model.module.state_dict()
        else:
            checkpoint['classifier'] = model.classifier
            checkpoint['state_dict'] = model.state_dict()

    elif model_name == 'resnet50':
        if multi_gpu:
            checkpoint['fc'] = model.module.fc
            checkpoint['state_dict'] = model.module.state_dict()
        else:
            checkpoint['fc'] = model.fc
            checkpoint['state_dict'] = model.state_dict()

    # Add the optimizer
    checkpoint['optimizer'] = model.optimizer
    checkpoint['optimizer_state_dict'] = model.optimizer.state_dict()

    # Save the data to the path
    torch.save(checkpoint, path)

# %%
save_checkpoint(model, path=checkpoint_path)

# %% [markdown]
# **Loading Checkpoints**

# %%
def load_checkpoint(path):

    """Load a PyTorch model checkpoint

    Params
    --------
        path (str): saved model checkpoint. Must start with `model_name-` and end in '.pth'

    Returns
    --------
        None, save the `model` to `path`

    """

    # Get the model name
    model_name = path.split('-')[0]
    assert (model_name in ['vgg16', 'resnet50'
                           ]), "Path must have the correct model name"

    # Load in checkpoint
    checkpoint = torch.load(path)

    if model_name == 'vgg16':
        model = models.vgg16(weights = 'DEFAULT')
        # Make sure to set parameters as not trainable
        for param in model.parameters():
            param.requires_grad = False
        model.classifier = checkpoint['classifier']

    elif model_name == 'resnet50':
        model = models.resnet50(weights = 'DEFAULT')
        # Make sure to set parameters as not trainable
        for param in model.parameters():
            param.requires_grad = False
        model.fc = checkpoint['fc']

    # Load in the state dict
    model.load_state_dict(checkpoint['state_dict'])

    total_params = sum(p.numel() for p in model.parameters())
    print(f'{total_params:,} total parameters.')
    total_trainable_params = sum(
        p.numel() for p in model.parameters() if p.requires_grad)
    print(f'{total_trainable_params:,} total gradient parameters.')

    # Move to gpu
    if multi_gpu:
        model = nn.DataParallel(model)

    if train_on_gpu:
        model = model.to('cuda')

    # Model basics
    model.class_to_idx = checkpoint['class_to_idx']
    model.idx_to_class = checkpoint['idx_to_class']
    model.epochs = checkpoint['epochs']

    # Optimizer
    optimizer = checkpoint['optimizer']
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    return model, optimizer

# %%
model, optimizer = load_checkpoint(path=checkpoint_path)
# Out:
# 24,040,286 total parameters.
# 532,254 total gradient parameters.

# %% [markdown]
# **Inference**

# %%
def process_image(image_path):
    """Process an image path into a PyTorch tensor"""

    image = Image.open(image_path)
    # Resize
    img = image.resize((256, 256))

    # Center crop
    width = 256
    height = 256
    new_width = 224
    new_height = 224

    left = (width - new_width) / 2
    top = (height - new_height) / 2
    right = (width + new_width) / 2
    bottom = (height + new_height) / 2
    img = img.crop((left, top, right, bottom))

    # Convert to numpy, transpose color dimension and normalize
    img = np.array(img).transpose((2, 0, 1)) / 256

    # Standardization
    means = np.array([0.485, 0.456, 0.406]).reshape((3, 1, 1))
    stds = np.array([0.229, 0.224, 0.225]).reshape((3, 1, 1))

    img = img - means
    img = img / stds

    img_tensor = torch.Tensor(img)

    return img_tensor

# %%
def predict(image_path, model, topk=5):
    """Make a prediction for an image using a trained model

    Params
    --------
        image_path (str): filename of the image
        model (PyTorch model): trained model for inference
        topk (int): number of top predictions to return

    Returns

    """
    real_class = image_path.split('/')[-2]

    # Convert to pytorch tensor
    img_tensor = process_image(image_path)

    # Resize
    if train_on_gpu:
        img_tensor = img_tensor.view(1, 3, 224, 224).cuda()
    else:
        img_tensor = img_tensor.view(1, 3, 224, 224)

    # Set to evaluation
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(img_tensor)
        ps = torch.exp(out)

        # Find the topk predictions
        topk, topclass = ps.topk(topk, dim=1)

        # Extract the actual classes and probabilities
        top_classes = [
            model.idx_to_class[class_] for class_ in topclass.cpu().numpy()[0]
        ]
        top_p = topk.cpu().numpy()[0]

        return img_tensor.cpu().squeeze(), top_p, top_classes, real_class

# %%
np.random.seed = 100


def random_test_image():
    """Pick a random test image from the test directory"""
    c = np.random.choice(categories)
    root = testdir +"/"+ c + '/'
    img_path = root + np.random.choice(os.listdir(root))
    return img_path


_ = imshow_tensor(process_image(random_test_image()))

# %%
img, top_p, top_classes, real_class = predict(random_test_image(), model,topk=2)

# %%
top_p, top_classes, real_class
# Out:
# (array([9.9973005e-01, 2.0591999e-04], dtype=float32),
#  ['Moringa Oleifera (Drumstick)', 'Carissa Carandas (Karanda)'],
#  'Moringa Oleifera (Drumstick)')

# %%
top_p
# Out:
# array([9.9973005e-01, 2.0591999e-04], dtype=float32)

# %% [markdown]
# **Display Preds**

# %%
def display_prediction(image_path, model, topk):
    """Display image and preditions from model"""

    # Get predictions
    img, ps, classes, y_obs = predict(image_path, model, topk)
    # Convert results to dataframe for plotting
    result = pd.DataFrame({'p': ps}, index=classes)

    # Show the image
    plt.figure(figsize=(16, 5))
    ax = plt.subplot(1, 2, 1)
    ax, img = imshow_tensor(img, ax=ax)

    # Set title to be the actual class
    ax.set_title(y_obs, size=20)

    ax = plt.subplot(1, 2, 2)
    # Plot a bar plot of predictions
    result.sort_values('p')['p'].plot.barh(color='blue', edgecolor='k', ax=ax)
    plt.xlabel('Predicted Probability')
    plt.tight_layout()

# %%
display_prediction(random_test_image(), model, topk=3)

# %% [markdown]
# **Testing Accuracy**

# %%
def k_accuracy(output, target, topk=(1, )):
    """Compute the topk accuracy(s)"""
    if train_on_gpu:
        output = output.to('cuda')
        target = target.to('cuda')

    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # Find the predicted classes and transpose
        _, pred = output.topk(k=maxk, dim=1, largest=True, sorted=True)
        pred = pred.t()

        # Determine predictions equal to the targets
        correct = pred.eq(target.reshape(1, -1).expand_as(pred))

        res = []

        # For each k, find the percentage of correct
        for k in topk:

            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)

            # Precision: TP / (TP + FP)
            precision = correct_k / maxk

            # Recall: TP / (TP + FN)
            recall = correct_k / target.sum()

            # F1-score: 2 * (precision * recall) / (precision + recall)
            f1 = 2 * (precision * recall) / (precision + recall)

            res.append((correct_k.mul_(100.0 / batch_size).item(), precision.item(), recall.item(), f1.item()))


        return res

# %%
testiter = iter(dataloaders['test'])
# Get a batch of testing images and labels
features, targets = next(testiter)

if train_on_gpu:
    res = k_accuracy(model(features.to('cuda')), targets, topk=(1, 5))
else:
    res = k_accuracy(model(features), targets, topk=(1, 5))

print(res)
print("first tuple is top 1 and other is top 5, of accuracy, precicion, recall and F1 scores respectively")
# Out:
# [(97.54768371582031, 71.5999984741211, 0.07190199196338654, 0.14365972578525543), (99.72752380371094, 73.20000457763672, 0.07350873947143555, 0.14687000215053558)]
# first tuple is top 1 and other is top 5, of accuracy, precicion, recall and F1 scores respectively

# %%
def accuracy(output, target, topk=(1, )):
    """Compute the topk accuracy(s)"""
    if train_on_gpu:
        output = output.to('cuda')
        target = target.to('cuda')

    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # Find the predicted classes and transpose
        _, pred = output.topk(k=maxk, dim=1, largest=True, sorted=True)
        pred = pred.t()

        # Determine predictions equal to the targets
        correct = pred.eq(target.reshape(1, -1).expand_as(pred))

        res = []

        # For each k, find the percentage of correct
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size).item())
        return res

# %% [markdown]
# **Function to Evaluate Model Over All Classes**

# %%
def evaluate(model, test_loader, criterion, topk=(1, 3, 5)):
    """Measure the performance of a trained PyTorch model

    Params
    --------
        model (PyTorch model): trained cnn for inference
        test_loader (PyTorch DataLoader): test dataloader
        topk (tuple of ints): accuracy to measure

    Returns
    --------
        results (DataFrame): results for each category

    """
    confusion_matrix = torch.zeros(n_classes, n_classes)
    classes = []
    losses = []
    # Hold accuracy results
    acc_results = np.zeros((len(test_loader.dataset), len(topk)))
    i = 0

    model.eval()
    with torch.no_grad():

        # Testing loop
        for data, targets in test_loader:

            # Tensors to gpu
            if train_on_gpu:
                data, targets = data.to('cuda'), targets.to('cuda')

            # Raw model output
            out = model(data)
            _, predscm = torch.max(out, 1)
            for t, p in zip(targets.view(-1), predscm.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

            # Iterate through each example
            for pred, true in zip(out, targets):
                # Find topk accuracy
                acc_results[i, :] = accuracy(
                    pred.unsqueeze(0), true.unsqueeze(0), topk)
                classes.append(model.idx_to_class[true.item()])
                # Calculate the loss
                loss = criterion(pred.view(1, n_classes), true.view(1))
                losses.append(loss.item())
                i += 1

    # Send results to a dataframe and calculate average across classes
    results = pd.DataFrame(acc_results, columns=[f'top{i}' for i in topk])
    results['class'] = classes
    results['loss'] = losses
    results = results.groupby(classes).mean()

    return results.reset_index().rename(columns={'index': 'class'}),confusion_matrix

criterion = nn.NLLLoss()
# Evaluate the model on all the training data
results,confusion_matrix = evaluate(model, dataloaders['test'], criterion)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.0f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(f'outputs/confusion_matrix.png')
    return plt

# %%
classnames = [model.idx_to_class[i] for i in range(0,n_classes)]

# %%
plt.figure(figsize=(20,20))
plt = plot_confusion_matrix(confusion_matrix, classnames)
# Out:
# Confusion matrix, without normalization

# %%
def cm_as_dataframe(cm):
    cm = pd.DataFrame(cm)
    cm.columns = classnames
    cm.index = classnames
    cm = cm.reset_index()
    return cm

cm_as_dataframe(confusion_matrix.cpu().numpy()).to_csv(f'outputs/confmat.csv',index=None)

# %%
print(f"Overall Accuracy:{confusion_matrix.diag().sum()/confusion_matrix.sum()}")
# Out:
# Overall Accuracy:0.975476861000061

# %%
results = results.merge(cnt_df,left_on='class',right_on='cat')

# %%
results
# Out:
#                                            class        top1        top3  \
# 0                        Alpinia Galanga (Rasna)   90.000000  100.000000
# 1               Amaranthus Viridis (Arive-Dantu)   95.833333  100.000000
# 2           Artocarpus Heterophyllus (Jackfruit)   72.727273   90.909091
# 3                      Azadirachta Indica (Neem)  100.000000  100.000000
# 4                          Basella Alba (Basale)   95.238095  100.000000
# 5               Brassica Juncea (Indian Mustard)  100.000000  100.000000
# 6                     Carissa Carandas (Karanda)  100.000000  100.000000
# 7                           Citrus Limon (Lemon)  100.000000  100.000000
# 8                Ficus Auriculata (Roxburgh fig)  100.000000  100.000000
# 9                  Ficus Religiosa (Peepal Tree)  100.000000  100.000000
# 10                        Hibiscus Rosa-sinensis   88.888889  100.000000
# 11                            Jasminum (Jasmine)   92.857143  100.000000
# 12                      Mangifera Indica (Mango)  100.000000  100.000000
# 13                                 Mentha (Mint)  100.000000  100.000000
# 14                  Moringa Oleifera (Drumstick)   93.333333   93.333333
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)  100.000000  100.000000
# 16                      Murraya Koenigii (Curry)  100.000000  100.000000
# 17                    Nerium Oleander (Oleander)  100.000000  100.000000
# 18           Nyctanthes Arbor-tristis (Parijata)  100.000000  100.000000
# 19                    Ocimum Tenuiflorum (Tulsi)  100.000000  100.000000
# 20                           Piper Betle (Betel)  100.000000  100.000000
# 21        Plectranthus Amboinicus (Mexican Mint)  100.000000  100.000000
# 22               Pongamia Pinnata (Indian Beech)  100.000000  100.000000
# 23                       Psidium Guajava (Guava)  100.000000  100.000000
# 24                 Punica Granatum (Pomegranate)  100.000000  100.000000
# 25                   Santalum Album (Sandalwood)  100.000000  100.000000
# 26                       Syzygium Cumini (Jamun)  100.000000  100.000000
# 27                  Syzygium Jambos (Rose Apple)  100.000000  100.000000
# 28    Tabernaemontana Divaricata (Crape Jasmine)  100.000000  100.000000
# 29         Trigonella Foenum-graecum (Fenugreek)  100.000000  100.000000
#
#           top5      loss                                           cat  \
# 0   100.000000  0.232751                       Alpinia Galanga (Rasna)
# 1   100.000000  0.179712              Amaranthus Viridis (Arive-Dantu)
# 2    90.909091  0.663539          Artocarpus Heterophyllus (Jackfruit)
# 3   100.000000  0.047417                     Azadirachta Indica (Neem)
# 4   100.000000  0.062897                         Basella Alba (Basale)
# 5   100.000000  0.094753              Brassica Juncea (Indian Mustard)
# 6   100.000000  0.082910                    Carissa Carandas (Karanda)
# 7   100.000000  0.058402                          Citrus Limon (Lemon)
# 8   100.000000  0.166052               Ficus Auriculata (Roxburgh fig)
# 9   100.000000  0.028061                 Ficus Religiosa (Peepal Tree)
# 10  100.000000  0.191253                        Hibiscus Rosa-sinensis
# 11  100.000000  0.146141                            Jasminum (Jasmine)
# 12  100.000000  0.009804                      Mangifera Indica (Mango)
# 13  100.000000  0.016359                                 Mentha (Mint)
# 14  100.000000  0.351285                  Moringa Oleifera (Drumstick)
# 15  100.000000  0.084925  Muntingia Calabura (Jamaica Cherry-Gasagase)
# 16  100.000000  0.170219                      Murraya Koenigii (Curry)
# 17  100.000000  0.065861                    Nerium Oleander (Oleander)
# 18  100.000000  0.066302           Nyctanthes Arbor-tristis (Parijata)
# 19  100.000000  0.121329                    Ocimum Tenuiflorum (Tulsi)
# 20  100.000000  0.055239                           Piper Betle (Betel)
# 21  100.000000  0.085561        Plectranthus Amboinicus (Mexican Mint)
# 22  100.000000  0.028377               Pongamia Pinnata (Indian Beech)
# 23  100.000000  0.011844                       Psidium Guajava (Guava)
# 24  100.000000  0.009871                 Punica Granatum (Pomegranate)
# 25  100.000000  0.055799                   Santalum Album (Sandalwood)
# 26  100.000000  0.003862                       Syzygium Cumini (Jamun)
# 27  100.000000  0.022328                  Syzygium Jambos (Rose Apple)
# 28  100.000000  0.036307    Tabernaemontana Divaricata (Crape Jasmine)
# 29  100.000000  0.025954         Trigonella Foenum-graecum (Fenugreek)
#
#     train_cnt  val_cnt  test_cnt
# 0          30       10        10
# 1          73       25        24
# 2          33       12        11
# 3          36       12        12
# 4          62       20        21
# 5          20        7         7
# 6          44       15        15
# 7          34       12        11
# 8          30       10        10
# 9          38       12        13
# 10         26        8         9
# 11         43       14        14
# 12         37       12        13
# 13         58       19        20
# 14         46       16        15
# 15         34       11        11
# 16         36       12        12
# 17         37       12        13
# 18         24        8         8
# 19         31       11        10
# 20         29       10         9
# 21         29       10         9
# 22         37       12        12
# 23         39       13        13
# 24         47       16        16
# 25         35       11        12
# 26         23        8         8
# 27         34       11        11
# 28         34       11        11
# 29         22        7         7

# %%
results.to_csv(f'outputs/test_accuracy.csv',index=None)

# %% [markdown]
# **check category**

# %%
def display_category(model, category, n=4):
    """Display predictions for a category
    """
    category_results = results.loc[results['class'] == category]
    #print(category_results.iloc[:, :10], '/n')

    images = np.random.choice(
        os.listdir(testdir + "/"+category + '/'), size=n, replace=False)

    for img in images:
        display_prediction(testdir +"/"+ category + '/' + img, model, 5)

# %%
display_category(model, 'Alpinia Galanga (Rasna)', n = 3 )

# %% [markdown]
# **Test Time Augmentation**

# %%
# Image transformations
tta_random_image_transforms = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])  # Imagenet standards
    ])

# %%
# Datasets from folders
ttadata = {
    'test':
    datasets.ImageFolder(root=testdir, transform=tta_random_image_transforms)
}

# Dataloader iterators
ttadataloader = {
    'test': DataLoader(ttadata['test'], batch_size=512, shuffle=False,num_workers=0)
}

# %%
def tta_preds_n_averaged(model, test_loader,n=5):
    """
    Returns the TTA preds from a trained PyTorch model

    Params
    --------
        model (PyTorch model): trained cnn for inference
        test_loader (PyTorch DataLoader): test dataloader

    Returns
    --------
        results (array): results for each category
    """

    # Hold results
    results = np.zeros((len(test_loader.dataset), n_classes))
    bs = test_loader.batch_size
    model.eval()
    with torch.no_grad():
        #aug loop:
        for _ in range(n):
            # Testing loop
            tmp_pred = np.zeros((len(test_loader.dataset), n_classes))
            for i,(data, targets) in enumerate(tqdm.tqdm(test_loader)):

                # Tensors to gpu
                if train_on_gpu:
                    data, targets = data.to('cuda'), targets.to('cuda')

                # Raw model output
                out = model(data)
                tmp_pred[i*bs:(i+1)*bs] = np.array(out.cpu())

            results+=tmp_pred
    return results/n

# %%
preds_tta = tta_preds_n_averaged(model, ttadataloader['test'])
# Out:
# 100%|██████████| 1/1 [00:12<00:00, 12.14s/it]
# 100%|██████████| 1/1 [00:07<00:00,  7.84s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.77s/it]
# 100%|██████████| 1/1 [00:09<00:00,  9.21s/it]
# 100%|██████████| 1/1 [00:07<00:00,  7.80s/it]

# %%
preds_tta_index = np.argmax(preds_tta,axis=1)
print(f"TTA Accuracy: {sum(ttadata['test'].targets==preds_tta_index)/len(preds_tta_index)}")
# Out:
# TTA Accuracy: 0.989100817438692

# %%
preddf = pd.DataFrame({'ttapreds':preds_tta_index,'truelabel':ttadata['test'].targets})
preddf['tta_acc'] = preddf['ttapreds'] == preddf['truelabel']
preddf['class'] = preddf['truelabel'].apply(lambda x: idx_to_class[x])
category_tta= preddf.groupby(['class']).aggregate({'tta_acc':np.mean}).reset_index()

# %%
ttaresults = results.merge(category_tta,on='class',how='left')[['class','top1','tta_acc', 'train_cnt', 'val_cnt',
       'test_cnt']]

# %%
ttaresults.columns = ['class', 'normal_acc', 'tta_acc', 'train_cnt', 'val_cnt', 'test_cnt']

# %%
ttaresults['tta_acc']*=100

# %%
ttaresults
# Out:
#                                            class  normal_acc     tta_acc  \
# 0                        Alpinia Galanga (Rasna)   90.000000  100.000000
# 1               Amaranthus Viridis (Arive-Dantu)   95.833333  100.000000
# 2           Artocarpus Heterophyllus (Jackfruit)   72.727273   81.818182
# 3                      Azadirachta Indica (Neem)  100.000000  100.000000
# 4                          Basella Alba (Basale)   95.238095  100.000000
# 5               Brassica Juncea (Indian Mustard)  100.000000  100.000000
# 6                     Carissa Carandas (Karanda)  100.000000  100.000000
# 7                           Citrus Limon (Lemon)  100.000000  100.000000
# 8                Ficus Auriculata (Roxburgh fig)  100.000000   90.000000
# 9                  Ficus Religiosa (Peepal Tree)  100.000000  100.000000
# 10                        Hibiscus Rosa-sinensis   88.888889  100.000000
# 11                            Jasminum (Jasmine)   92.857143  100.000000
# 12                      Mangifera Indica (Mango)  100.000000  100.000000
# 13                                 Mentha (Mint)  100.000000  100.000000
# 14                  Moringa Oleifera (Drumstick)   93.333333   93.333333
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)  100.000000  100.000000
# 16                      Murraya Koenigii (Curry)  100.000000  100.000000
# 17                    Nerium Oleander (Oleander)  100.000000  100.000000
# 18           Nyctanthes Arbor-tristis (Parijata)  100.000000  100.000000
# 19                    Ocimum Tenuiflorum (Tulsi)  100.000000  100.000000
# 20                           Piper Betle (Betel)  100.000000  100.000000
# 21        Plectranthus Amboinicus (Mexican Mint)  100.000000  100.000000
# 22               Pongamia Pinnata (Indian Beech)  100.000000  100.000000
# 23                       Psidium Guajava (Guava)  100.000000  100.000000
# 24                 Punica Granatum (Pomegranate)  100.000000  100.000000
# 25                   Santalum Album (Sandalwood)  100.000000  100.000000
# 26                       Syzygium Cumini (Jamun)  100.000000  100.000000
# 27                  Syzygium Jambos (Rose Apple)  100.000000  100.000000
# 28    Tabernaemontana Divaricata (Crape Jasmine)  100.000000  100.000000
# 29         Trigonella Foenum-graecum (Fenugreek)  100.000000  100.000000
#
#     train_cnt  val_cnt  test_cnt
# 0          30       10        10
# 1          73       25        24
# 2          33       12        11
# 3          36       12        12
# 4          62       20        21
# 5          20        7         7
# 6          44       15        15
# 7          34       12        11
# 8          30       10        10
# 9          38       12        13
# 10         26        8         9
# 11         43       14        14
# 12         37       12        13
# 13         58       19        20
# 14         46       16        15
# 15         34       11        11
# 16         36       12        12
# 17         37       12        13
# 18         24        8         8
# 19         31       11        10
# 20         29       10         9
# 21         29       10         9
# 22         37       12        12
# 23         39       13        13
# 24         47       16        16
# 25         35       11        12
# 26         23        8         8
# 27         34       11        11
# 28         34       11        11
# 29         22        7         7

# %% [markdown]
# # TFLITE

# %%
import tensorflow as tf

model = tf.keras.models.load_model('/content/trained.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
